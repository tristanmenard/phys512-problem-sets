# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate, integrate

# %% [markdown]
# ## PHYS 512 - Problem Set 1
# Tristan Ménard<br>
# 260675783
# ### Problem 1
# #### a)
#
# By evaluating our function at 4 points $(x\pm\delta and x\pm2\delta)$, we can eliminate the third order Taylor series term from the numerical derivative. Thus, the truncation error becomes a fifth order term.
#
# To do so, first I write out the Taylor expansions for $f(x\pm\delta)$ and $f(x\pm2\delta)$.
#
# $
# f(x+\delta) = f(x)+\delta f'(x)+\frac{1}{2}\delta^2f''(x)+\frac{1}{6}\delta^3f^{(3)}(x)+\frac{1}{24}\delta^4f^{(4)}(x)+\frac{1}{120}\delta^5f^{(5)}(x) + \ldots \\
# f(x-\delta) = f(x)-\delta f'(x)+\frac{1}{2}\delta^2f''(x)-\frac{1}{6}\delta^3f^{(3)}(x)+\frac{1}{24}\delta^4f^{(4)}(x)-\frac{1}{120}\delta^5f^{(5)}(x) + \ldots \\
# f(x+2\delta) = f(x)+2\delta f'(x)+2\delta^2f''(x)+\frac{4}{3}\delta^3f^{(3)}(x)+\frac{2}{3}\delta^4f^{(4)}(x)+\frac{4}{15}\delta^5f^{(5)}(x) + \ldots \\
# f(x-2\delta) = f(x)-2\delta f'(x)+2\delta^2f''(x)-\frac{4}{3}\delta^3f^{(3)}(x)+\frac{2}{3}\delta^4f^{(4)}(x)-\frac{4}{15}\delta^5f^{(5)}(x) + \ldots
# $
#
# The even ordered terms of the Taylor series can be eliminated by combining similar equations.
#
# $
# f(x+\delta)-f(x-\delta) = 2\delta f'(x)+\frac{1}{3}\delta^3f^{(3)}(x)+\frac{1}{60}\delta^5f^{(5)}(x)+... \\
# f(x+2\delta)-f(x-2\delta) = 4\delta f'(x)+\frac{8}{3}\delta^3f^{(3)}(x)+\frac{8}{15}\delta^5f^{(5)}(x)+...
# $
#
# Finally, these can be combined again to eliminate the third order term in the expansion as well, so that the truncation error is on the order of the fifth order term.
#
# $
# \begin{align}
# f'(x) &= \frac{8(f(x+\delta)-8f(x-\delta))-(f(x+2\delta)-f(x-2\delta))}{12\delta} \\
# f'(x) &= \frac{16\delta f'(x)+\frac{2}{15}\delta^5f^{(5)}(x)-4\delta f'(x)-\frac{8}{15}\delta^5 f^{(5)}(x)}{12\delta} \\
# f'(x) &= f'(x) - \frac{1}{30}\delta^4f^{(5)}(x)
# \end{align}
# $
#
# Therefore, the new operator for the 4-point numerical derivative is $f'(x)\approx\frac{-f(x+2\delta)+8f(x+\delta)-8f(x-\delta)+f(x-2\delta)}{12\delta}$, and the truncation error is now on the order of $\delta^4f^{(5)}(x)$.
#
# #### b)
#
# The total error $E$ in the numerical derivative will be the sum of the truncation error and the roundoff error. We already know that the truncation error is on the order of $\delta^4f^{(5)}(x)$. The roundoff error can be found if we add a small error $\epsilon_i$ to each function evaluation term in the operator. Assume $\epsilon_i$ is approximately equal to the machine precision $\sim 10^{-16}$, and that change in f(x) over $\delta$ or $2\delta$ is small.
#
# $
# \begin{align}
# E &= f'(x) - \frac{-f(x+2\delta)(1+\epsilon_1)+8f(x+\delta)(1+\epsilon_2)-8f(x-\delta)(1+\epsilon_3)+f(x-2\delta)(1+\epsilon_4)}{12\delta} \\
# E &= \frac{1}{30}\delta^4f^{(5)}(x) - \frac{-f(x+2\delta)\epsilon_1+8f(x+\delta)\epsilon_2-8f(x-\delta)\epsilon_3+f(x-2\delta)\epsilon_4}{12\delta} \\
# E &\approx \delta^4f^{(5)}(x) - \frac{f(x)}{12\delta}(-\epsilon_1+8\epsilon_2-8\epsilon_3+\epsilon_4)
# \end{align}
# $
#
# In the worst case, all roundoff errors add together such that $-\epsilon_1+8\epsilon_2-8\epsilon_3+\epsilon_4\leq18\epsilon$ where $\epsilon$ is the machine precision. So, putting it all together, the total error is
#
# $
# E \lesssim \delta^4f^{(5)}(x) - \frac{3\epsilon f(x)}{2\delta}.
# $
#
# Now, minimize the total error with respect to $\delta$ to get the optimal $\delta$.
#
# $
# \begin{align}
# \frac{\partial E}{\partial \delta} = 0 &= 4\delta^3 f^{(5)}(x) - \frac{3\epsilon f(x)}{2\delta^2} \\
# \frac{3}{2}\epsilon f(x) &= 4\delta^5 f^{(5)}(x) \\
# \delta_{\text{opt}} &\sim \left(\frac{3\epsilon f(x)}{8f^{(5)}(x)}\right)^{1/5}
# \end{align}
# $
#
# Check that it is roughly correct:

# %%
def FourPointDerivative(func, x, delta):
    """
    Takes a function func, an x value, and a step size delta as inputs.
    Returns the numerical derivative of func(x) using the 4-point operator derived above.
    """
    return (-func(x+2*delta)+8*func(x+delta)-8*func(x-delta)+func(x+2*delta))/(12*delta)

def DeltaOpt(f, f_prime5, x, precision):
    """
    Takes a function f, its fifth derivative f_prime5, an x value, and the machine precision as inputs.
    Returns the roughly derived optimal step size to use for differentiating.
    """
    return (3*precision*f(x)/(8*f_prime5(x)))**(1/5)

# %% [markdown]
# Let's look at the absolute error in the derivative of two functions for many values of $\delta$.

# %%
# Give the desired functions to numerically integrate:
f1 = lambda x: np.exp(x)
f2 = lambda x: np.exp(0.01*x)

# We will need the analytic 5th derivative of both these functions later on:
f1_prime5 = f1
f2_prime5 = lambda x: (0.01**5)*np.exp(0.01*x)

# Pick a x value to check the optimal delta estimate
x = 0.5

# Look at how the absolute error in the numerical derivative changes for values of delta between 10^-17 and 10^0
delta = np.logspace(-17,0,200)
# Compute the 4-point numerical derivative for the above delta values
f1_prime_num = FourPointDerivative(f1, x, delta)
f2_prime_num = FourPointDerivative(f2, x, delta)

# Check the numerical derivative against the exact analytic derivative
f1_prime_exact = np.exp(x)
f2_prime_exact = 0.01*np.exp(0.01*x)
AbsError1 = np.abs(f1_prime_exact-f1_prime_num)
AbsError2 = np.abs(f2_prime_exact-f2_prime_num)

# %%
plt.loglog(delta, AbsError1, label='f(x) = exp(x)')
plt.loglog(delta, AbsError2, label='f(x) = exp(0.01x)')
plt.xlim(delta.min(), delta.max())
plt.xlabel(r'$\delta$')
plt.ylabel('Absolute error in the derivative')
plt.legend()
plt.show()

# %% [markdown]
# It is difficult to see the minimum in either of the stable parts of the absolute error lines. They appear flat, but this is not the case. By looking at the difference in absolute error between adjacent points, the minima appear clearly around $10^{-4}$ for $f(x)=e^x$ and around $10^{-2}$ for $f(x)=e^{0.01x}$.

# %%
plt.loglog(delta[0:-1], np.abs(np.diff(AbsError1)), label='f(x) = exp(x)')
plt.loglog(delta[0:-1], np.abs(np.diff(AbsError2)), label='f(x) = exp(0.01x)')
plt.xlim(delta.min(), delta.max())
plt.xlabel(r'$\delta$')
plt.ylabel('Point-point difference in the absolute error')
plt.legend()
plt.show()

# %%
# What do I estimate the optimal delta to be?
delta_opt_1 = DeltaOpt(f1, f1_prime5, x, 1e-16) # set the machine precision to 10^-16
delta_opt_2 = DeltaOpt(f2, f2_prime5, x, 1e-16)
print('The optimal step size for each function should be:\nf(x)=exp(x):\t\t'+repr(delta_opt_1)+'\nf(x)=exp(0.01x):\t'+repr(delta_opt_2)) # right order of magnitude!
# Out:
# The optimal step size for each function should be:
# f(x)=exp(x):		0.00051856864466832378
# f(x)=exp(0.01x):	0.051856864466832395

# %% [markdown]
# The rough formula derived for the optimal step size is on the correct order of magnitude.

# %% [markdown]
# ### Problem 2

# %%
# Load the data
data = np.loadtxt('lakeshore.txt')
T = data[:,0] #K
V = data[:,1] #V
dVdT = data[:,2] #mV/K

# Data is ordered by ascending temperature; reorder it by ascending voltage
index = np.argsort(V)
V = V[index]
T = T[index]

# %%
def CubicSplineInterp(x, y, xi):
    """
    Returns the interpolated value(s) xi from a 1D cubic spline of your x and y data points.
    Also, computes the linear interpolation between data points for the same xi values.
    The absolute difference between the value(s) from the cubic spline interpolation (yi) and the value(s) from the linear interpolation (yi_linear) is returned as the rough error (yi_err).
    x : array-like
        The x data points to interpolate
    y : array-like
        The y data points to interpolate
    xi : float or array-like
        The value(s) of x where we want to interpolate new y value(s)
    """
    xi = np.asarray(xi)
    spln = interpolate.splrep(x, y)
    yi = interpolate.splev(xi, spln)
    linear = interpolate.interp1d(x, y, 'linear')
    yi_linear = linear(xi)
    yi_err = np.abs(yi_linear-yi) # because the baseline is a simple linear interpolation, the error is likely overestimated
    return yi, yi_err

# %% [markdown]
# Verify that this function outputs the interpolated temperature for a given voltage value. I chose to interpolate the temperature for a voltage of 1V.

# %%
xx = 1.0
yy, yy_err = CubicSplineInterp(V, T, xx)
print('The interpolated temperature for a voltage of {:}V is {:} +/- {:}K.'.format(xx, yy, yy_err))
# Out:
# The interpolated temperature for a voltage of 1.0V is 92.8996409775585 +/- 0.029361831417276107K.

# %% [markdown]
# Show the interpolated values for the whole range.

# %%
xx_full = np.linspace(V[0],V[-1],2001)
yy_full, yy_err_full = CubicSplineInterp(V, T, xx_full)

plt.plot(V, T, '.-', label='raw data')
plt.plot(xx_full, yy_full, label='cubic spline')
plt.plot(xx, yy, '*', label='interpolated temperature at 1V')
plt.xlim(V[0],V[-1])
plt.xlabel('Voltage [V]')
plt.ylabel('Temperature [K]')
plt.legend()
plt.show()

# %% [markdown]
# ### Problem 3

# %%
def better_integrate(fun, a, b, tol, y0_last=None, y2_last=None, y4_last=None, verbose=False):
    """
    A 5-point recursive variable step size integrator that does not call f(x) multiple times for the same x.
    fun : function
        The function for the integrand
    a : float
        The integration's start value
    b : float
        The integration's end value
    tol : float
        The difference between the 5-point and the 3-point integration must be smaller than this tolerance to be considered final
    y0_last : float or None (default)
        The first f(x) value that was passed from the previous iteration
    y2_last : float or None (default)
        The midpoint f(x) value that was passed from the previous iteration
    y4_last : float or None (default)
        The last f(x) value that was passed from the previous iteration
    """
    if y0_last is None: # only occurs for the first iteration
        x = np.linspace(a,b,5)
        y = fun(x)
        neval = len(x) # neval keeps track of the number of f(x) calls
    else:
        dx = (b-a)/4
        y = np.array([y0_last, fun(a+dx), y2_last, fun(a+3*dx), y4_last]) # uses f(x) values that were computed in the previous iteration
        neval = 2 # two new f(x) calls
    f1 = (y[0]+4*y[2]+y[4])/6*(b-a)
    f2 = (y[0]+4*y[1]+2*y[2]+4*y[3]+y[4])/12.0*(b-a) 
    myerr = np.abs(f2-f1)
    if verbose:
        print([a,b,f1,f2,y])
    if myerr<tol:
        return (16*f1-f2)/15, myerr, neval
    else:
        mid = 0.5*(b+a)
        f_left, err_left, neval_left = better_integrate(fun, a, mid, tol/2.0, y0_last=y[0], y2_last=y[1], y4_last=y[2], verbose=verbose)
        f_right, err_right, neval_right = better_integrate(fun, mid, b, tol/2.0, y0_last=y[2], y2_last=y[3], y4_last=y[4], verbose=verbose)
        neval = neval+neval_left+neval_right
        f = f_left+f_right
        err = err_left+err_right
        return f, err, neval

# %% [markdown]
# For comparison purposes, here is the simple recursive variable step size integrator we wrote in class.

# %%
def simple_integrate(fun,a,b,tol):
    x=np.linspace(a,b,5)
    dx=(b-a)/4.0
    y=fun(x)
    neval=len(x) #let's keep track of function evaluations
    f1=(y[0]+4*y[2]+y[4])/6.0*(b-a)
    f2=(y[0]+4*y[1]+2*y[2]+4*y[3]+y[4])/12.0*(b-a)
    myerr=np.abs(f2-f1)
#     print([a,b,f1,f2])
    if (myerr<tol):
        return (16.0*f2-f1)/15.0,myerr,neval
    else:
        mid=0.5*(b+a)
        f_left,err_left,neval_left=simple_integrate(fun,a,mid,tol/2.0)
        f_right,err_right,neval_right=simple_integrate(fun,mid,b,tol/2.0)
        neval=neval+neval_left+neval_right
        f=f_left+f_right
        err=err_left+err_right
        return f,err,neval

# %% [markdown]
# Let's compare the number of function calls in each method for $f(x)=e^x$, $f(x)=\sin(x)$, and $f(x) = e^{-\frac{x^2}{2}}$.
#
# ### $ f(x)=e^x$

# %%
f_better, err_better, neval_better = better_integrate(np.exp, -1, 1, 1e-3, verbose=True) # set verbose to True to see the inner workings of the integrator
f_simple, err_simple, neval_simple = simple_integrate(np.exp, -1, 1, 1e-3)
pred = np.exp(1)-np.exp(-1)
print('\nBETTER_INTEGRATE: f,err,neval are ' + repr([f_better,err_better,neval_better])+' with err ' + repr(np.abs(f_better-pred)))
print('SIMPLE_INTEGRATE: f,err,neval are ' + repr([f_simple,err_simple,neval_simple])+' with err ' + repr(np.abs(f_simple-pred)))
# Out:
# [-1, 1, 2.3620537565434958, 2.3511948318802554, array([ 0.36787944,  0.60653066,  1.        ,  1.64872127,  2.71828183])]
# [-1, 0.0, 0.63233368000366263, 0.63213417532053229, array([ 0.36787944,  0.47236655,  0.60653066,  0.77880078,  1.        ])]
# [0.0, 1, 1.7188611518765928, 1.7183188419217472, array([ 1.        ,  1.28402542,  1.64872127,  2.11700002,  2.71828183])]
# [0.0, 0.5, 0.64873524478759115, 0.64872214895065505, array([ 1.        ,  1.13314845,  1.28402542,  1.45499141,  1.64872127])]
# [0.5, 1, 1.0695835971341561, 1.0695620057492419, array([ 1.64872127,  1.86824596,  2.11700002,  2.39887529,  2.71828183])]
#
# BETTER_INTEGRATE: f,err,neval are [2.3506681347190752, 0.00023419190498064069, 13] with err 0.00026574743147245172
# SIMPLE_INTEGRATE: f,err,neval are [2.3504027172267641, 0.00023419190498064069, 25] with err 3.299391613253988e-07

# %% [markdown]
# My new integrator requires 13 function evaluations while the old one requires 25.
#
# ### $f(x)=\sin(x)$

# %%
f_better, err_better, neval_better = better_integrate(np.sin, 0, np.pi, 1e-3) # set verbose to True to see the inner workings of the integrator
f_simple, err_simple, neval_simple = simple_integrate(np.sin, 0, np.pi, 1e-3)
pred = 2
print('BETTER_INTEGRATE: f,err,neval are ' + repr([f_better,err_better,neval_better])+' with err ' + repr(np.abs(f_better-pred)))
print('SIMPLE_INTEGRATE: f,err,neval are ' + repr([f_simple,err_simple,neval_simple])+' with err ' + repr(np.abs(f_simple-pred)))
# Out:
# BETTER_INTEGRATE: f,err,neval are [2.0002860085417513, 0.00025257890045238263, 17] with err 0.00028600854175131474
# SIMPLE_INTEGRATE: f,err,neval are [1.9999997524545721, 0.00025257890045238263, 35] with err 2.4754542793381518e-07

# %% [markdown]
# My new integrator requires 17 function evaluations while the old one requires 35.
#
# ### $f(x)=e^{-\frac{x^2}{2}}$

# %%
fun = lambda x: np.exp(-x**2/2)
f_better, err_better, neval_better = better_integrate(fun, -1, 1, 1e-3) # set verbose to True to see the inner workings of the integrator
f_simple, err_simple, neval_simple = simple_integrate(fun, -1, 1, 1e-3)
pred = 0
print('BETTER_INTEGRATE: f,err,neval are ' + repr([f_better,err_better,neval_better]))
print('SIMPLE_INTEGRATE: f,err,neval are ' + repr([f_simple,err_simple,neval_simple]))
# Out:
# BETTER_INTEGRATE: f,err,neval are [1.7122307647876585, 0.00087012155980004113, 9]
# SIMPLE_INTEGRATE: f,err,neval are [1.7112446270198851, 0.00087012155980004113, 15]

# %% [markdown]
# My new integrator requires 9 function evaluations while the old one requires 15.
#
# So, for these functions, we see that somewhere around 40 to 50% less function evaluations are required. For integrations that require more iterations, the smarter integrator could eliminate the need for nearly 60% of the original integrator's function calls.
#
# ### Problem 4

# %% [markdown]
# $
# \begin{align}
# E &= \frac{1}{4\pi\epsilon_0}\int \frac{\sigma}{r^2}\hat{r}da\ \ \ \ \text{where}\ r=\sqrt{z^2+R^2-2zR\cos\theta}\ \ \text{and}\ \hat{r}=\frac{z-R\cos\theta}{r}. \\
# E(z) &= \frac{1}{4\pi\epsilon_0} \int_0^{2\pi}\int_0^\pi \frac{\sigma R^2\sin\theta(z-R\cos\theta)}{(z^2+R^2-2zR\cos\theta)^{3/2}}d\theta d\phi \\
# E(z) &= \frac{1}{4\pi\epsilon_0} \frac{q}{2} \int_0^\pi \frac{\sin\theta(z-R\cos\theta)}{(z^2+R^2-2zR\cos\theta)^{3/2}}d\theta\ \ \ \ \text{where}\ q=4\pi\sigma R^2.
# \end{align}
# $
#
# There is a singularity in the integrand at $z=R$, but as demonstrated below, quad doesn't care and calculates the integral when $z=R$ to be equal to 1.

# %%
R = 1 # choose R=1
zs = np.linspace(0,2,101)
integrand = lambda theta: (z-R*np.cos(theta))*np.sin(theta)/(z**2+R**2-2*z*R*np.cos(theta))**1.5

integral_quad = []
for i in range(len(zs)):
    z = zs[i]
    integral_quad.append(integrate.quad(integrand, 0, np.pi)[0])
    
plt.plot(zs, integral_quad, '.')
plt.xlabel('z')
plt.ylabel('Integral value with quad')
plt.show()

# %% [markdown]
# On the other hand, the custom recursive variable step size integrator I wrote in problem 3 is not able to calculate the value of the integral for $z=R$.

# %%
# using the same z values as before (includes z=R=1)
integral_custom = []
for i in range(len(zs)):
    z = zs[i]
    integral_custom.append(better_integrate(integrand, 0, np.pi, 1e-3, verbose=True)[0])
# Out:
# [0, 3.141592653589793, -6.4122356457392988e-17, -8.4201105038257884e-17, array([ -0.00000000e+00,  -5.00000000e-01,  -6.12323400e-17,
#          5.00000000e-01,   1.22464680e-16])]
# [0, 3.141592653589793, 0.041862781867144067, -0.0043246576181297479, array([ -0.00000000e+00,  -5.06911661e-01,   1.99880060e-02,
#          4.92787914e-01,   1.17709227e-16])]
# [0, 1.5707963267948966, -0.52560380228740311, -0.50105309299501755, array([-0.        , -0.36577157, -0.50691166, -0.34271052,  0.01998801])]
# [0, 0.7853981633974483, -0.25787212667652354, -0.25722427687160154, array([-0.        , -0.19891279, -0.36577157, -0.47399787, -0.50691166])]
# [0, 0.39269908169872414, -0.076014940212864701, -0.076003461467282665, array([-0.        , -0.10152665, -0.19891279, -0.28819774, -0.36577157])]
# [0.39269908169872414, 0.7853981633974483, -0.18120933665873681, -0.18118325313434183, array([-0.36577157, -0.42852885, -0.47399787, -0.5004395 , -0.50691166])]
# [0.7853981633974483, 1.5707963267948966, -0.2431809663184939, -0.24269650172532861, array([-0.50691166, -0.46029527, -0.34271052, -0.1736509 ,  0.01998801])]
# [0.7853981633974483, 1.1780972450961724, -0.17611266248644575, -0.1760898637031981, array([-0.50691166, -0.49329724, -0.46029527, -0.40937704, -0.34271052])]
# [1.1780972450961724, 1.5707963267948966, -0.066583839238882836, -0.066577827381792701, array([-0.34271052, -0.26305775, -0.1736509 , -0.07805331,  0.01998801])]
# [1.5707963267948966, 3.141592653589793, 0.52127914466927339, 0.50092625764573173, array([  1.99880060e-02,   3.63434560e-01,   4.92787914e-01,
#          3.41873162e-01,   1.17709227e-16])]
# [1.5707963267948966, 2.356194490192345, 0.25741610155959083, 0.25684505414692194, array([ 0.01998801,  0.20838787,  0.36343456,  0.46277671,  0.49278791])]
nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 3.805868090239881e-268, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.9029340451199405e-268, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 9.514670225599702e-269, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 4.757335112799851e-269, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.3786675563999256e-269, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.1893337781999628e-269, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 5.946668890999814e-270, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.973334445499907e-270, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.4866672227499535e-270, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 7.433336113749767e-271, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 3.7166680568748837e-271, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.8583340284374418e-271, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 9.291670142187209e-272, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 4.6458350710936046e-272, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.3229175355468023e-272, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.1614587677734012e-272, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 5.807293838867006e-273, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.903646919433503e-273, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.4518234597167514e-273, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 7.259117298583757e-274, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 3.6295586492918786e-274, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.8147793246459393e-274, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 9.073896623229697e-275, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 4.536948311614848e-275, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.268474155807424e-275, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.134237077903712e-275, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 5.67118538951856e-276, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.83559269475928e-276, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.41779634737964e-276, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 7.0889817368982e-277, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 3.5444908684491e-277, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.77224543422455e-277, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 8.86122717112275e-278, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 4.430613585561375e-278, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.2153067927806876e-278, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.1076533963903438e-278, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 5.538266981951719e-279, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.7691334909758595e-279, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.3845667454879298e-279, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 6.922833727439649e-280, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 3.4614168637198244e-280, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.7307084318599122e-280, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 8.653542159299561e-281, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 4.3267710796497805e-281, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.1633855398248903e-281, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.0816927699124451e-281, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 5.408463849562226e-282, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.704231924781113e-282, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.3521159623905564e-282, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 6.760579811952782e-283, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 3.380289905976391e-283, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.6901449529881955e-283, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 8.450724764940978e-284, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 4.225362382470489e-284, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.1126811912352444e-284, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.0563405956176222e-284, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 5.281702978088111e-285, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 2.6408514890440555e-285, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.3204257445220277e-285, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 6.602128722610139e-286, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 3.3010643613050694e-286, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 1.6505321806525347e-286, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# [0, 8.252660903262673e-287, nan, nan, array([ nan,  nan,  nan,  nan,  nan])]
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-18-a129b3f36343> in <module>()
#       3 for i in range(len(zs)):
#       4     z = zs[i]
# ----> 5     integral_custom.append(better_integrate(integrand, 0, np.pi, 1e-3, verbose=True)[0])
#
# <ipython-input-11-d183722d6613> in better_integrate(fun, a, b, tol, y0_last, y2_last, y4_last, verbose)
#      34     else:
#      35         mid = 0.5*(b+a)
# ---> 36         f_left, err_left, neval_left = better_integrate(fun, a, mid, tol/2.0, y0_last=y[0], y2_last=y[1], y4_last=y[2], verbose=verbose)
#      37         f_right, err_right, neval_right = better_integrate(fun, mid, b, tol/2.0, y0_last=y[2], y2_last=y[3], y4_last=y[4], verbose=verbose)
#      38         neval = neval+neval_left+neval_right
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-11-d183722d6613> in better_integrate(fun, a, b, tol, y0_last, y2_last, y4_last, verbose)
#      34     else:
#      35         mid = 0.5*(b+a)
# ---> 36         f_left, err_left, neval_left = better_integrate(fun, a, mid, tol/2.0, y0_last=y[0], y2_last=y[1], y4_last=y[2], verbose=verbose)
#      37         f_right, err_right, neval_right = better_integrate(fun, mid, b, tol/2.0, y0_last=y[2], y2_last=y[3], y4_last=y[4], verbose=verbose)
#      38         neval = neval+neval_left+neval_right
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# But it still works fine when $z\neq R$.

# %%
zs_new = np.linspace(0,2,100) # does not include z=R=1
integral_custom = []
for i in range(len(zs_new)):
    z = zs_new[i]
    integral_custom.append(better_integrate(integrand, 0, np.pi, 1e-3)[0])
    
plt.plot(zs_new, integral_custom, '.')
plt.show()
