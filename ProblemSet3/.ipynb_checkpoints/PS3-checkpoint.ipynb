# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## PHYS 512 - Problem Set 2
# Tristan Ménard<br>
# 260675783
# ### Problem 1

# %%
data = np.loadtxt('WMAP_9yr_combined_power_spectrum.txt')
multipole_index = data[:,0]
power_spectrum = data[:,1]
err = data[:,2]

# %%
import camb

# %%
def get_spectrum(pars, lmax=1200):
    H0 = pars[0]
    ombh2 = pars[1]
    omch2 = pars[2]
    tau = pars[3]
    As = pars[4]
    ns = pars[5]
    pars = camb.CAMBparams()
    pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2, mnu=0.06, tau=tau)
    pars.InitPower.set_params(As=As, ns=ns, r=0)
    pars.set_for_lmax(lmax, lens_potential_accuracy=0)
    results = camb.get_results(pars)
    powers = results.get_cmb_power_spectra(pars, CMB_unit='muK')
    cmb = powers['total']
    tt = cmb[:,0]
    return tt

# %%
pars = [65,0.02,0.1,0.05,2e-9,0.96]
cmb = get_spectrum(pars)
cmb_cut = cmb[2:len(power_spectrum)+2] # keep only the CMB model for the multipole values are in the data (2-1200)

# %%
plt.figure(figsize=(10,8))
plt.errorbar(multipole_index, power_spectrum, yerr=err, fmt='.', barsabove=True)
plt.plot(multipole_index, cmb_cut)
plt.xlabel(r'Multipole index, $l$')
plt.ylabel('CMB power spectrum')
plt.show()

# %%
resid = power_spectrum - cmb_cut
chisq = np.sum((resid/err)**2)
print('Chi-squared = '+repr(chisq))
# Out:
# Chi-squared = 1588.4257943681487

# %% [markdown]
# ### Problem 2

# %%
def get_spectrum_derivs(pars, delta=1e-8, lmax=1199):
    H0, ombh2, omch2, As, ns = pars
    tau = 0.05
    fun = get_spectrum([H0, ombh2, omch2, tau, As, ns], lmax)
    dH0 = (get_spectrum([H0+delta, ombh2, omch2, tau, As, ns], lmax) - ref)/delta
    dombh2 = (get_spectrum([H0, ombh2+delta, omch2, tau, As, ns], lmax) - ref)/delta
    domch2 = (get_spectrum([H0, ombh2, omch2+delta, tau, As, ns], lmax) - ref)/delta
    dAs = (get_spectrum([H0, ombh2, omch2, tau, As+delta, ns], lmax) - ref)/delta
    dns = (get_spectrum([H0, ombh2, omch2, tau, As, ns+delta], lmax) - ref)/delta
    
    fun = fun[2:]
    dH0 = dH0[2:]
    dombh2 = dombh2[2:]
    domch2 = domch2[2:]
    dAs = dAs[2:]
    dns = dns[2:]
    
    derivs = np.zeros([lmax, len(pars)])
    derivs[:,0] = dH0
    derivs[:,1] = dombh2
    derivs[:,2] = domch2
    derivs[:,3] = dAs
    derivs[:,4] = dns
    return fun, derivs

# %%
def update_lmbda(lmbda, success):
    if success == False:
        if lmbda == 0:
            lmbda = 1
        else:
            lmbda = 0.5*lmbda
    else:
        if lmbda < 0.2:
            lmbda = 0
        else:
            lmbda = lmbda/2
    return lmbda

# %%
pars = [65, 0.02, 0.1, 2e-9, 0.96] # H0, ombh2, omch2, As, ns
cmb, derivs = get_spectrum_derivs(pars)

lmbda = 0
chisq_threshold = 0.1
Ninv = np.linalg.inv(np.diag(err))
resid = power_spectrum - cmb
chisq = np.sum((resid/err)**2)
print('Initial guess: chi-squared = '+repr(chisq))

for i in range(30):
    grad = 2*np.dot(derivs.transpose(), np.dot(Ninv, resid))
    curve = 2*np.dot(derivs.transpose(), np.dot(Ninv, derivs))
    curve = curve + lmbda*np.diag(np.diag(curve))
    new_pars = pars + np.dot(np.linalg.inv(curve), grad)
    new_cmb, new_derivs = get_spectrum_derivs(new_pars)
    new_resid = power_spectrum - new_cmb
    new_chisq = np.sum((new_resid/err)**2)
    delta_chisq = new_chisq - chisq
    print('Step '+repr(i+1)+': chi-squared change = '+repr(delta_chisq))
    
    if new_chisq <= chisq:
        resid = new_resid
        chisq = new_chisq
        derivs = new_derivs
        pars = new_pars
        lmbda = update_lmbda(lmbda, success=True)
        print('Updating lambda to '+repr(lmbda)+'.')
        if lmbda == 0 and np.abs(delta_chisq) < chisq_threshold and i > 0:
            print('Stopping after '+repr(i)+' iterations.')
            break
    else:
        lmbda = update_lmbda(lmbda, success=False)
        print('Reject! Updating lambda to '+repr(lmbda)+'.')
# Out:
# Initial guess: chi-squared = 1588.4366720631901
# Step 1: chi-squared change = -345.2775033030098
# Updating lambda to 0.
# Step 2: chi-squared change = 144.49044777697827
# Reject! Updating lambda to 1.
# Step 3: chi-squared change = -4.0913641110269054
# Updating lambda to 0.5.
# Step 4: chi-squared change = -2.0672800398547224
# Updating lambda to 0.25.
# Step 5: chi-squared change = -0.6695403685025667
# Updating lambda to 0.125.
# Step 6: chi-squared change = -0.060734883879376866
# Updating lambda to 0.
# Stopping after 5 iterations.

# %%
covariance = np.linalg.inv(curve)
print('L-M optimized fit chi-squared = '+repr(new_chisq))
print('Best-fit parameters are:')
print('H0 = '+repr(pars[0])+' +/- '+repr(np.diag(covariance)[0]))
print('ombh2 = '+repr(pars[1])+' +/- '+repr(np.diag(covariance)[1]))
print('omch2 = '+repr(pars[2])+' +/- '+repr(np.diag(covariance)[2]))
print('As = '+repr(pars[3])+' +/- '+repr(np.diag(covariance)[3]))
print('ns = '+repr(pars[4])+' +/- '+repr(np.diag(covariance)[4]))
plt.figure(figsize=(10,8))
plt.errorbar(multipole_index, power_spectrum, yerr=err, fmt='.', color='gray', barsabove=True)
plt.plot(multipole_index, cmb, 'b', label='Initial guess')
plt.plot(multipole_index, new_cmb, 'r', label='L-M optimized fit')
plt.xlabel(r'Multipole index, $l$')
plt.ylabel('CMB power spectrum')
plt.xlim(2,1200)
plt.legend()
plt.show()
# Out:
# L-M optimized fit chi-squared = 1236.2702493569168
# Best-fit parameters are:
# H0 = 65.85400872358632 +/- 4.474357108644236e-21
# ombh2 = 0.022397582955908362 +/- 4.4743571592541624e-21
# omch2 = 0.1187175951848956 +/- 4.474348702466132e-21
# As = 2.0808693920079198e-09 +/- 1.5165957230939617e-25
# ns = 0.9653990915616834 +/- 4.474356902159098e-21

# %% [markdown]
# ### Problem 3
